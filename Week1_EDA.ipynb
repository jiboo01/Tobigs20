# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv('./WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.info()

# 결측치 없음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.hist(bins=50, figsize=(16, 24))

# 분포 시각화
# skewed 되어있는 컬럼만 밑에서 이상치 확인

# %%
num_data = df.select_dtypes([np.number])
obj_data = df.select_dtypes([object])

# 수치형/범주형 데이터 분리하기

# %%
num_data
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0      41       1102                 1          2              1
# 1      49        279                 8          1              1
# 2      37       1373                 2          2              1
# 3      33       1392                 3          4              1
# 4      27        591                 2          1              1
# ...   ...        ...               ...        ...            ...
# 1465   36        884                23          2              1
# 1466   39        613                 6          1              1
# 1467   27        155                 4          3              1
# 1468   49       1023                 2          3              1
# 1469   34        628                 8          3              1
#
#       EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                  1                        2          94               3
# ...

# %%
plt.figure(figsize=(16, 16))
sns.heatmap(num_data.corr(), annot=True, cmap='YlGnBu', fmt='.2f')
# Out:
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %%
num_data.iloc[:,-4:].boxplot(figsize=(15,10))
# Out:
# <Axes: >
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %%
pd.DataFrame(num_data['MonthlyIncome']).boxplot(figsize=(15,10))
# Out:
# <Axes: >
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %%
num_data[['DistanceFromHome', 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears']].boxplot(figsize=(15,10))
# Out:
# <Axes: >
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# findfont: Font family 'NanumGothic' not found.
# ...

# %%
num_data_att = pd.concat([df['Attrition'], num_data], axis=1)
num_data_att
# Out:
#      Attrition  Age  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0          Yes   41       1102                 1          2              1
# 1           No   49        279                 8          1              1
# 2          Yes   37       1373                 2          2              1
# 3           No   33       1392                 3          4              1
# 4           No   27        591                 2          1              1
# ...        ...  ...        ...               ...        ...            ...
# 1465        No   36        884                23          2              1
# 1466        No   39        613                 6          1              1
# 1467        No   27        155                 4          3              1
# 1468        No   49       1023                 2          3              1
# 1469        No   34        628                 8          3              1
#
# ...

# %%
out1 = num_data_att[num_data_att['Attrition']=='Yes']
out1.hist(bins=50, figsize=(16, 24))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'DailyRate'}>,
#         <Axes: title={'center': 'DistanceFromHome'}>,
#         <Axes: title={'center': 'Education'}>,
#         <Axes: title={'center': 'EmployeeCount'}>],
#        [<Axes: title={'center': 'EmployeeNumber'}>,
#         <Axes: title={'center': 'EnvironmentSatisfaction'}>,
#         <Axes: title={'center': 'HourlyRate'}>,
#         <Axes: title={'center': 'JobInvolvement'}>,
#         <Axes: title={'center': 'JobLevel'}>],
#        [<Axes: title={'center': 'JobSatisfaction'}>,
#         <Axes: title={'center': 'MonthlyIncome'}>,
#         <Axes: title={'center': 'MonthlyRate'}>,
#         <Axes: title={'center': 'NumCompaniesWorked'}>,
#         <Axes: title={'center': 'PercentSalaryHike'}>],
#        [<Axes: title={'center': 'PerformanceRating'}>,
#         <Axes: title={'center': 'RelationshipSatisfaction'}>,
#         <Axes: title={'center': 'StandardHours'}>,
# ...

# %%
out1_desc = out1.describe()
out1_desc
# Out:
#               Age    DailyRate  DistanceFromHome   Education  EmployeeCount  \
# count  237.000000   237.000000        237.000000  237.000000          237.0
# mean    33.607595   750.362869         10.632911    2.839662            1.0
# std      9.689350   401.899519          8.452525    1.008244            0.0
# min     18.000000   103.000000          1.000000    1.000000            1.0
# 25%     28.000000   408.000000          3.000000    2.000000            1.0
# 50%     32.000000   699.000000          9.000000    3.000000            1.0
# 75%     39.000000  1092.000000         17.000000    4.000000            1.0
# max     58.000000  1496.000000         29.000000    5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# count      237.000000               237.000000  237.000000      237.000000
# mean      1010.345992                 2.464135   65.573840        2.518987
# ...

# %%
stay1 = num_data_att[num_data_att['Attrition']=='No']
stay1_desc = stay1.describe()
stay1_desc
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1233.000000  1233.000000       1233.000000  1233.000000         1233.0
# mean     37.561233   812.504461          8.915653     2.927007            1.0
# std       8.888360   403.208379          8.012633     1.027002            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      31.000000   477.000000          2.000000     2.000000            1.0
# 50%      36.000000   817.000000          7.000000     3.000000            1.0
# 75%      43.000000  1176.000000         13.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1233.000000              1233.000000  1233.000000     1233.000000
# mean      1027.656123                 2.771290    65.952149        2.770479
# ...

# %%
monthlyIncome = pd.concat([pd.DataFrame(out1_desc['MonthlyIncome']), pd.DataFrame(stay1_desc['MonthlyIncome'])])
monthlyIncome
# Out:
#        MonthlyIncome
# count     237.000000
# mean     4787.092827
# std      3640.210367
# min      1009.000000
# 25%      2373.000000
# 50%      3202.000000
# 75%      5916.000000
# max     19859.000000
# count    1233.000000
# mean     6832.739659
# std      4818.208001
# min      1051.000000
# 25%      3211.000000
# 50%      5204.000000
# 75%      8834.000000
# max     19999.000000

# %%
obj_data

# Attrition, Gender, MaritalStatus, Over18, OverTime 은 0, 1로
# BusinessTravel은 순서가 반영된 인코딩
# Department, EducationField, JobRole은 서로 관련없으므로 원핫인코딩
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
obj_data['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
# 라벨인코더 선언 및 Fitting
le = LabelEncoder()
le.fit(obj_data['Attrition'])

# 인코딩한 데이터로 변환
le_encoded = le.transform(obj_data['Attrition'])

# 결과물을 확인하면 array 형태로 나옵니다.
# 아래는 라벨 인코딩으로 만들어낸 데이터를 데이터 프레임으로 만들어주는 코드입니다.
new_cat = pd.DataFrame(le_encoded, columns = ['Attrition_enc'])


le = LabelEncoder()
le.fit(obj_data['Attrition'])


le_encoded = le.transform(obj_data['Attrition'])


new_cat = pd.DataFrame(le_encoded, columns = ['Attrition_enc'])

# 아래 코드를 실행시키면 인코딩된 class를 확인할 수 있습니다.
le.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
new_cat
# Out:
#       Attrition_enc
# 0                 1
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# ...             ...
# 1465              0
# 1466              0
# 1467              0
# 1468              0
# 1469              0
#
# [1470 rows x 1 columns]

# %%
ohe = OneHotEncoder(sparse=False)
ohe.fit(obj_data)

# 인코딩한 데이터로 변환
ohe_encoded = ohe.transform(obj_data)

# 결과물을 확인하면 array 형태로 나옵니다.
# 아래는 기존의 데이터와 원핫 인코딩으로 만들어낸 데이터를 concat하는 코드입니다.
new_cat = pd.DataFrame(ohe_encoded)
obj_data = pd.concat([obj_data, new_cat], axis=1)

# 아래 코드를 실행시키면 인코딩된 class를 확인할 수 있습니다.
ohe.categories_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 ohe = OneHotEncoder(sparse=False)
#       2 ohe.fit(obj_data)
#       4 # 인코딩한 데이터로 변환
#
# NameError: name 'OneHotEncoder' is not defined
